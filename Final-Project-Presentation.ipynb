# %% [markdown]
# # Final Project Presentation : ANURA
#
# # Marina Salama
#
# # March 16, 2017

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Anura-pic-1.png')

# %% [markdown]
# # =>Introduction :
#
# * Anura (commonly known as frogs) constitutes the vast majority (6,285 species out of a total of 7,125, or 88%; AmphibiaWeb 2013) of living amphibian diversity, and is also among the most diverse groups of vertebrates (Zhang, 2013)
#
# * Anura is the clade of living frogs and their close fossil relatives.
#
# * The name Anura refers to the lack of a tail.
#
# * Compared with other amphibians, frogs have a wide distribution and occupy a diversity of habitats such as forests, grasslands, rivers, waterfalls, mudflats, mountaintops, and deserts (Zhang, 2013)
#
# * A general opinion is that chromosome evolution in frogs has been much slower than in other vertebrate groups (Bogart, 1991)
#
# =>Referances:
#
# * Zhang, Peng, Dan Liang, Rong-Li Mao, David M. Hillis, David B. Wake, and David C. Cannatella. "Efficient Sequencing of Anuran MtDNAs and a Mitogenomic Exploration of the Phylogeny and Evolution of Frogs." Molecular Biology and Evolution. Oxford University Press, 11 May 2013. Web. 10 Mar. 2017.
#
# * Green, David Martin., and Stanley Keith. Sessions. Amphibian Cytogenetics and Evolution. San Diego: Academic, 1991. Print.
#
# * Duellman, W. E. 1975. On the classification of frogs. Occ. Pap. Mus. Nat. Hist. Univ. Kansas (42):1-15.

# %% [markdown]
# # => Why Anura:
#
# * I was shocked by the diversity of species frogs have, and as a result became increasingly interested in researching the species a bit more
# * At first, I began to look for speciation diversity but soon discovered that I already knew that of course they have a diverse array!
# * As a result, my project focuses on extinction over time for Anura

# %% [markdown]
# # 1) Code To Get Me Started:
#
#
# * Note: after cleaning out my data on the terminal using the "tail" command, I appended the cleaned information to a new csv file named " formatted_frog_data.csv"
# * This is one of my functional codes from previous weeks (with slight editing.) This is an important starting point which will help me import and modify my csv of my chosen species even further
# * This first step is very essential because with this modification, I will next be able to move on and create my desired graphs !
# * NOTE: with the aid of prof. Alfaro, the addition of a few steps from my previous code has a purpose of cleaning up my "genus" columns in order to have it better prepared for graphing in ggplots

# %%
import csv
import re


pattern = r'[A-Z][a-z]+'   #get me capitalized words !
with open("/home/eeb177-student/Desktop/eeb-177/final-project/formatted_frog_data.csv", newline='') as infh:
    reader = csv.reader(infh)
    
    for row in reader:
        if row[6] == "species":
            genus = row[5].split(" ")[0]
            ss = (row[5])
            searchObj = re.search(pattern, ss)
            if searchObj:
                print(searchObj.group(0))
            else:
                print("no match")
# Out:
# Cretasalia
# Gobiates
# Gobiates
# Enneabatrachus
# Eobatrachus
# Eopelobates
# Scaphiopus
# Scotiophryne
# Bufo
# Discoglossus
# Bufo
# Bufo
# Rana
# Thoraciliacus
# Cordicephalus
# Cordicephalus
# Bufo
# Bufo
# Pseudacris
# Rana
# Scaphiopus
# Scaphiopus
# Bufo
# Bufo
# Bufo
# Acris
# Pseudacris
# Pseudacris
# Hyla
# Hyla
# Hyla
# Rana
# Bufo
# Bufo
# Rana
# Rana
# Bufo
# Pseudacris
# Bufo
# Bufo
# Bufo
# Scaphiopus
# Rana
# Bufo
# Rana
# Scaphiopus
# Pseudacris
# Hyla
# Bufo
# Bufo
# Bufo
# Bufo
# Rana
# Bufo
# Hyla
# Hyla
# Rana
# Bufo
# Bufo
# Bufo
# Bufo
# Bufo
# Bufo
# Rana
# Rana
# Hyla
# Rana
# Rana
# Scaphiopus
# Scaphiopus
# Bufo
# Bufo
# Pseudacris
# Scaphiopus
# Scaphiopus
# Scaphiopus
# Bufo
# Scaphiopus
# Bufo
# Scaphiopus
# Scaphiopus
# Scaphiopus
# Rana
# Bufo
# Scaphiopus
# Rana
# Bufo
# Bufo
# Pseudacris
# Scaphiopus
# Rana
# Bufo
# Bufo
# Scaphiopus
# Rana
# Bufo
# Bufo
# Bufo
# Scaphiopus
# Scaphiopus
# Scaphiopus
# Litoria
# Limnodynastes
# Limnodynastes
# ...

# %% [markdown]
# # 2) This second code will further help me extract my desired data further to save in a csv:

# %%
import csv
import re

with open("/home/eeb177-student/Desktop/eeb-177/final-project/formatted-week-9-frog-data.csv", newline='') as infh:
    reader = csv.reader(infh)
    
    for row in reader:
        genus = row[0].split(" ")[0]
        print(genus + "," + row[1] + "," + row[2] + "," + row[3])
# Out:
# Eodiscoglossus,oxoniensis,164.7000,167.7000
# Comobatrachus,aenigmatis,145.0000,157.3000
# Enneabatrachus,hechti,145.0000,157.3000
# Eobatrachus,agilis,145.0000,157.3000
# Rhadinosteus,parvus,152.1000,157.3000
# Cordicephalus,gracilis,113.0000,145.0000
# Thoraciliacus,rostriceps,113.0000,145.0000
# Aygroua,anoualensis,139.8000,145.0000
# Shomronella,jordanica,139.8000,145.0000
# Sunnybatrachus,purbeckensis,140.2000,145.0000
# Liaobatrachus,macilentus,113.0000,130.0000
# Liaobatrachus,beipiaoensis,122.4600,130.0000
# Liaobatrachus,grabaui,122.4600,130.0000
# Liaobatrachus,zhaoi,122.4600,130.0000
# Montsechobatrachus,gaudryi,125.0000,130.0000
# Eodiscoglossus,santonjae,125.4500,130.0000
# Gracilibatrachus,avallei,125.4500,130.0000
# Iberobatrachus,angelae,125.4500,130.0000
# Neusibatrachus,wilferti,125.0000,129.4000
# Arariphrynus,placidoi,112.0300,122.4600
# Cratia,gracilis,112.0300,122.4600
# Eurycephalella,alcinae,112.0300,122.4600
# Avitabatrachus,uliana,93.5000,99.6000
# ...

# %% [markdown]
# # 3)Finally, I attempted to create a function to help me extract extinct species from the dataset:

# %%
import csv

def extinct_frog(species):
    for row in reader:
        if row[2] > '0':    #basically anything that is now extinct
            print(row[0])
            
with open("/home/eeb177-student/Desktop/eeb-177/final-project/formatted-week-9-frog-data.csv", newline='') as infh:
    reader = csv.reader(infh)
    counter = 0
    for row in reader:
        print(str(counter) + ")" + row[0] + " " + "is extinct")
        counter += 1
# Out:
# 0)Eodiscoglossus is extinct
# 1)Comobatrachus is extinct
# 2)Enneabatrachus is extinct
# 3)Eobatrachus is extinct
# 4)Rhadinosteus is extinct
# 5)Cordicephalus is extinct
# 6)Thoraciliacus is extinct
# 7)Aygroua is extinct
# 8)Shomronella is extinct
# 9)Sunnybatrachus is extinct
# 10)Liaobatrachus is extinct
# 11)Liaobatrachus is extinct
# 12)Liaobatrachus is extinct
# 13)Liaobatrachus is extinct
# 14)Montsechobatrachus is extinct
# 15)Eodiscoglossus is extinct
# 16)Gracilibatrachus is extinct
# 17)Iberobatrachus is extinct
# 18)Neusibatrachus is extinct
# 19)Arariphrynus is extinct
# 20)Cratia is extinct
# 21)Eurycephalella is extinct
# 22)Avitabatrachus is extinct
# 23)Oumtkoutia is extinct
# 24)Aralobatrachus is extinct
# 25)Estesina is extinct
# 26)Gobiates is extinct
# 27)Gobiates is extinct
# 28)Gobiates is extinct
# 29)Kizylkuma is extinct
# 30)Saevesoederberghia is extinct
# 31)Gobiates is extinct
# 32)Gobiatoides is extinct
# 33)Procerobatrachus is extinct
# ...

# %% [markdown]
# # 4)Using GGPLOT in R:
#
# The data set below contains information about the first and last appearance for each unique species in the family Anura that is represented in the PBDB:
# ==========================================================================================================================================================
#
# ![](final-project-ggplots-anura-occ_files/figure-markdown_strict/unnamed-chunk-11-1.png)

# %% [markdown]
# # 5)Next, I used matplotlib in python to create a richness plot in order to see the frequency over time and analyze anything that is NOT "0" which means it is extinct:

# %%
# load in the file

in_file = open("/home/eeb177-student/Desktop/eeb-177/final-project/formatted-week-9-frog-data.csv")
in_file.readline()
# set up empty dictionaries

species_richness = {}

# iterate through every line in the file
for line in in_file:
    #print(line)
    
    # It's a tab delimited file, so we can split the contents up into 
    # the component rows
    items = line.split(",")
    
    # Save some important pieces of information as variables
    species = items[1]
    min_age = float(items[2])
    
    
    # Use the variables to populate our three empty lists
    species_richness[species] = min_age

# %%
import matplotlib.pyplot as plt


# Most plotting happens on lists, not dictionaries-
# so, let's convert our data into a list
min_age = list(species_richness.values())

# We're ready to make a histogram!
plt.hist(min_age)
plt.xlabel('Time in million')
# a y-axis label
plt.ylabel('Species Richness')
# A main title for the graph
plt.title("Anura Species Richness")
plt.show()

# %% [markdown]
# # 6) Using package PaleobioDB in R to help me create plots which can help me get closer to anwering my desired question:

# %% [markdown]
# #  => What is Package PaleobioDB?
#
# * Includes 19 functions to wrap each endpoint of the PaleobioDB API, plus 8 functions to visualize and process the fossil data.

# %% [markdown]
# # Done in R:
#
#
# This first plot provides me with the number of species my dataset has and also helps me make sure that my dataset is large enough:
# =============================================================
#
# ![](final-project-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-3-1.png)
#
# Next is a map of occurences:
# =====================================
#
# ![](final-project-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-4-1.png)
#
# For general referance, here is a plot similar to the one I created in ggplots for species richness with the number of species across time:
# ==========================================================================================================================================
#
# ![](final-project-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-5-1.png)
#
#
# Finally, here is my desired overall extinction plot with the number of last appearances of species query across the time:
# =========================================================================================================================
#
# ![](final-project-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-6-1.png)

# %% [markdown]
# # Here is a link to my github, feel free to check it out !
#
# * https://github.com/mfsalama/eeb-177-final-project

# %% [markdown]
# # THANK YOU !

# %% [markdown]
# # QUESTIONS ?
