# %% [markdown]
# # =>Introduction (UPDATED):
#
# * Anura (commonly known as frogs) constitutes the vast majority (6,285 species out of a total of 7,125, or 88%; AmphibiaWeb 2013) of living amphibian diversity, and is also among the most diverse groups of vertebrates (Zhang, 2013)
# * Anura is the clade of living frogs and their close fossil relatives.
# * The name Anura refers to the lack of a tail.
# * Compared with other amphibians, frogs have a nearly cosmopolitan distribution and occupy a diversity of habitats such as forests, grasslands, rivers, waterfalls, mudflats, mountaintops, and deserts (Zhang, 2013)
# * The node-based name Anura was defined by Ford and Cannatella (1993) as the last common ancestor of living frogs and all its descendants. According to this definition,
# * Other names for Anura include: Anurans.
# * A general opinion is that chromosome evolution in frogs has been much slower than in vertebratte groups (Bogart, 1991)
#
#
# =>Referances:
#
# * Zhang, Peng, Dan Liang, Rong-Li Mao, David M. Hillis, David B. Wake, and David C. Cannatella. "Efficient Sequencing of Anuran MtDNAs and a Mitogenomic Exploration of the Phylogeny and Evolution of Frogs." Molecular Biology and Evolution. Oxford University Press, 11 May 2013. Web. 10 Mar. 2017.
#
# * Green, David Martin., and Stanley Keith. Sessions. Amphibian Cytogenetics and Evolution. San Diego: Academic, 1991. Print.
#
# * Duellman, W. E. 1975. On the classification of frogs. Occ. Pap. Mus. Nat. Hist. Univ. Kansas (42):1-15.

# %% [markdown]
# # =>My Project:
# * For my project, I have had more experiences with plants and other ecology animals
# * Conseuqntly, I was attempting to search up something new with many species
# * I was shocked by the massive amount of species frogs have, and as a result became increasingly more interested in researching the species a bit more
# * As a result, my project focuses on speciation changes over time of frogs (Anura)

# %% [markdown]
# # =>My Project Question (UPDATED):
# * What is the speciation change patterns over time for "Anura" ?

# %% [markdown]
# # 1) Code To Get Me Started (UPDATED):
#
# * This is one of my functional codes from previous weeks (with slight editing.) This is an important starting point which will help me import and modify my csv of my chosen species even further
# * This first step is very essential because with this modification, I will next be able to move on and create my desired graphs !
# * NOTE: with the aid of prof. Alfaro, the addition of a few steps from my previous code has a purpose of cleaning up my "genus" columns in order to have it better prepared for graphing in ggplots

# %%
import csv
import re


pattern = r'[A-Z][a-z]+'
with open("/home/eeb177-student/Desktop/eeb-177/final-project/formatted_frog_data.csv", newline='') as infh:
    reader = csv.reader(infh)
    
    for row in reader:
        if row[6] == "species":
            genus = row[5].split(" ")[0]
            #print(genus + "," + row[5] + "," + row[15] + "," + row[14])
            ss = (row[5])
            #print(ss)
            searchObj = re.search(pattern, ss)
            if searchObj:
                print(searchObj.group(0))
            else:
                print("no match")
# Out:
# Cretasalia
# Gobiates
# Gobiates
# Enneabatrachus
# Eobatrachus
# Eopelobates
# Scaphiopus
# Scotiophryne
# Bufo
# Discoglossus
# Bufo
# Bufo
# Rana
# Thoraciliacus
# Cordicephalus
# Cordicephalus
# Bufo
# Bufo
# Pseudacris
# Rana
# Scaphiopus
# Scaphiopus
# Bufo
# Bufo
# Bufo
# Acris
# Pseudacris
# Pseudacris
# Hyla
# Hyla
# Hyla
# Rana
# Bufo
# Bufo
# Rana
# Rana
# Bufo
# Pseudacris
# Bufo
# Bufo
# Bufo
# Scaphiopus
# Rana
# Bufo
# Rana
# Scaphiopus
# Pseudacris
# Hyla
# Bufo
# Bufo
# Bufo
# Bufo
# Rana
# Bufo
# Hyla
# Hyla
# Rana
# Bufo
# Bufo
# Bufo
# Bufo
# Bufo
# Bufo
# Rana
# Rana
# Hyla
# Rana
# Rana
# Scaphiopus
# Scaphiopus
# Bufo
# Bufo
# Pseudacris
# Scaphiopus
# Scaphiopus
# Scaphiopus
# Bufo
# Scaphiopus
# Bufo
# Scaphiopus
# Scaphiopus
# Scaphiopus
# Rana
# Bufo
# Scaphiopus
# Rana
# Bufo
# Bufo
# Pseudacris
# Scaphiopus
# Rana
# Bufo
# Bufo
# Scaphiopus
# Rana
# Bufo
# Bufo
# Bufo
# Scaphiopus
# Scaphiopus
# Scaphiopus
# Litoria
# Limnodynastes
# Limnodynastes
# Ranidella
# Geocrinia
# Sunnybatrachus
# Pelobates
# Pliobatrachus
# Bufo
# Pelobates
# Pliobatrachus
# Bufo
# Bufo
# Eopelobates
# Bufo
# Bufo
# Bufo
# Bufo
# Pelobates
# Bufo
# Bufo
# Rana
# Bufo
# Pliobatrachus
# Bufo
# Pelobates
# Pliobatrachus
# Bufo
# Rana
# Rana
# Pelobates
# Pelobates
# Pelobates
# Pelobates
# Pelobates
# Pelobates
# Pelobates
# Scotiophryne
# Pelobates
# Bufo
# Bufo
# Eopelobates
# Bufo
# Bufo
# Hyla
# Rana
# Thaumastosaurus
# Eodiscoglossus
# Albionbatrachus
# Bufo
# Latonia
# Latonia
# Latonia
# Bufo
# Rana
# Rana
# Rana
# Bufo
# Gobiates
# Rana
# Eopelobates
# Rana
# Tyrrellbatrachus
# Shelania
# Scotiophryne
# Palaeobatrachus
# Latonia
# Enigmatosaurus
# Enigmatosaurus
# Enigmatosaurus
# Enigmatosaurus
# Tyrrellbatrachus
# Tyrrellbatrachus
# Beelzebufo
# Hungarobatrachus
# Pachybatrachus
# Pipidae
# Rana
# Rana
# Calyptocephalella
# Neoprocoela
# Bufo
# Rana
# Rana
# Rana
# Bufo
# Eophractus
# Rana
# Discoglossus
# Bufo
# Bufo
# Hyla
# Rana
# Rana
# Discoglossus
# Discoglossus
# Bufo
# Discoglossus
# Discoglossus
# Bufo
# Hyla
# Bufo
# Rhinophrynus
# Scaphiopus
# Hyla
# Scaphiopus
# Eorhinophrynus
# Rana
# Rana
# Bufo
# Rana
# Bufo
# Scaphiopus
# Bufo
# Rana
# Vulcanobatrachus
# Bufo
# Palaeobatrachus
# Comobatrachus
# Gobiates
# Rhadinosteus
# Rana
# Rana
# Bufo
# Scaphiopus
# Wealdenbatrachus
# Bufo
# Eodiscoglossus
# Paradiscoglossus
# Paradiscoglossus
# Palaeobatrachus
# Theatonius
# Lechriodus
# Bufo
# Latonia
# Rana
# Bufo
# Eopelobates
# Bufo
# Bufo
# Leptodactylus
# Rana
# Xenopus
# Chelomophrynus
# Proacris
# Scaphiopus
# Bufo
# Microhyla
# Scaphiopus
# Gastrophryne
# Rana
# Rana
# Bufo
# Acris
# Pseudacris
# Hyla
# Hyla
# Hyla
# Bufo
# Rana
# Acris
# Bufo
# Scaphiopus
# Bufo
# Pseudacris
# Rana
# Rana
# Pseudacris
# Pseudacris
# Pseudacris
# Eleutherodactylus
# Syrrhophus
# Bufo
# Xenopus
# Rana
# Rana
# Bufo
# Beelzebufo
# Eleutherodactylus
# Bufo
# Bufo
# Rana
# Baurubatrachus
# Bufo
# Bufo
# Hyla
# Rana
# Rana
# Shomronella
# Eopelobates
# Singidella
# Llankibatrachus
# Llankibatrachus
# Eorubeta
# Hyla
# Rana
# Limnodynastes
# Australobatrachus
# Litoria
# Rana
# Macropelobates
# Miopelodytes
# Prodiscoglossus
# Zaphrissa
# Sunnybatrachus
# Rana
# Rana
# Arariphrynus
# Eurycephalella
# Cratia
# Mesophryne
# Wawelia
# Eoxenopoides
# Shelania
# Shelania
# Saltenia
# Laliostoma
# Ptychadena
# Rana
# Scaphiopus
# Scaphiopus
# Bufo
# Bufo
# Eleutherodactylus
# Eopelobates
# Bufo
# Hyla
# Rana
# Rana
# Rana
# Rhacophorus
# Hyla
# Rana
# Rana
# Rana
# Rana
# Rana
# Bufo
# Rana
# Bufo
# Bufo
# Scaphiopus
# Rana
# Rana
# Paralatonia
# Oumtkoutia
# Oumtkoutia
# Anura
# Bufo
# Hyla
# Hatzegobatrachus
# Avitabatrachus
# Yizhoubatrachus
# Aygroua
# Beelzebufo
# Neusibatrachus
# Callobatrachus
# Liaobatrachus
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiates
# Gobiatoides
# Kizylkuma
# Kizylkuma
# Kizylkuma
# Aralobatrachus
# Aralobatrachus
# Aralobatrachus
# Aralobatrachus
# Saevesoederberghia
# Saevesoederberghia
# Procerobatrachus
# Estesina
# Estesina
# Bakonybatrachus
# Rana
# Bufo
# Rana
# Rana
# Bufo
# Bufo
# Hyla
# Hyla
# Rana
# Rana
# Rana
# Rana
# Hyla
# Hyla
# Acris
# Pseudacris
# Hyla
# Bufo
# Bufo
# Hyla
# Pseudacris
# Rana
# Rana
# Rana
# Saltenia
# Saltenia
# Latonia
# Bufo
# Pseudacris
# Palaeobatrachus
# Elkobatrachus
# Spea
# Latonia
# Palaeobatrachus
# Bufo
# Hyla
# Latonia
# Latonia
# Latonia
# Pliobatrachus
# Bufo
# Bufo
# Bufo
# Bufo
# Pelobates
# Pelodytes
# Bufo
# Pelophylax
# Scaphiopus
# Bufo
# Bufo
# Gastrophryne
# Rana
# Palaeobatrachus
# Latonia
# Latonia
# Bufo
# Latonia
# Pelobates
# Bufo
# Liaobatrachus
# Iberobatrachus
# Gracilibatrachus
# Uberabatrachus
# Estesius
# Hyla
# Rana
# Scaphiopus
# Bufo
# Rana
# Scaphiopus
# Scaphiopus
# Bufo
# Bufo
# Rana
# Rana
# Rana
# Rana
# Scaphiopus
# Scaphiopus
# Bufo
# Bufo
# Rana
# Scaphiopus
# Bufo
# Pseudacris
# Bufo
# Microhyla
# Scaphiopus
# Rana
# Rhinophrynus
# Syrrhophus
# Leptodactylus
# Rana
# Bufo
# Rana
# Rana
# Scaphiopus
# Bufo
# Bufo
# Rana
# Scaphiopus
# Bufo
# Rana
# Pseudacris
# Bufo
# Bufo
# Acris
# Pseudacris
# Rana
# Acris
# Hyla
# Rana
# Rana
# Scaphiopus
# Hyla
# Microhyla
# Bufo
# Acris
# Rana
# Rana
# Eleutherodactylus
# Palaeobatrachus
# Palaeobatrachus
# Palaeobatrachus
# Scotiophryne
# Liaobatrachus
# Dalianbatrachus
# Liaobatrachus
# Ceratophrys
# Lepidobatrachus
# Ceratophrys
# Ceratophrys
# Lepidobatrachus
# Ceratophrys
# Montsechobatrachus
# Palaeobatrachus
# Leiopelma
# Leiopelma
# Leiopelma
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Beelzebufo
# Anchylorana
# Anchylorana
# Anchylorana
# Rana
# Rana
# Rana
# Rana
# Rana
# Rana
# Scaphiopus
# Neoscaphiopus
# Scaphiopus
# Hyla
# Scaphiopus
# Bufo
# Thaumastosaurus
# Thaumastosaurus
# Scaphiopus
# Bufo
# Bufo
# Rana
# Rana
# Scaphiopus
# Bufo
# Hyla
# Gastrophryne
# Rana
# Rana
# Rana
# Bufo
# Rana
# Hyla
# Palaeobatrachus
# Rana
# Latonia
# Rana
# Latonia
# Rana
# Latonia
# Rana
# Bufo
# Latonia
# Latonia
# Latonia
# Latonia
# Latonia
# Latonia
# Latonia
# Latonia
# Palaeobatrachus
# Palaeobatrachus
# Pelodytes
# Pelobates
# Pelobates
# Pelobates
# Pelobates
# Pelobates
# Bufo
# Bufo
# Hyla
# Hyla
# Hyla
# Hyla
# Hyla
# Eodiscoglossus
# Tyrrellbatrachus
# Tyrrellbatrachus
# Tyrrellbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Hensonbatrachus
# Ranoidea
# Ranoidea
# Ranoidea
# Ranoidea
# Latonia
# Latonia
# Lechriodus
# Latonia
# Prospea
# Leptodactylidae
# Leptodactylidae
# Anura
# Bufo
# Pelobates
# Litoria
# Crinia
# Limnodynastes
# Thaumastosaurus
# Bufo
# Rana
# Leiopelma
# Lechriodus
# Odontophrynus
# Bufo
# Pelobates
# Rana
# Bufo
# Bufo
# Tephrodytes
# Tephrodytes
# Tephrodytes
# Palaeobatrachus
# Palaeobatrachus
# Eopelobates
# Palaeobatrachus
# Eopelobates

# %% [markdown]
# # 2) Code # 2 to further clean out my data in a formatted csv and put everything together (UPDATED):

# %%
import csv
import re

with open("/home/eeb177-student/Desktop/eeb-177/final-project/formatted-week-9-frog-data.csv", newline='') as infh:
    reader = csv.reader(infh)
    
    for row in reader:
        genus = row[1].split(" ")[0]
        print(genus + "," + row[2] + "," + row[4] + "," + row[3])
# Out:
# Eodiscoglossus,oxoniensis,164.7000,167.7000
# Comobatrachus,aenigmatis,145.0000,157.3000
# Enneabatrachus,hechti,145.0000,157.3000
# Eobatrachus,agilis,145.0000,157.3000
# Rhadinosteus,parvus,152.1000,157.3000
# Cordicephalus,gracilis,113.0000,145.0000
# Thoraciliacus,rostriceps,113.0000,145.0000
# Aygroua,anoualensis,139.8000,145.0000
# Shomronella,jordanica,139.8000,145.0000
# Sunnybatrachus,purbeckensis,140.2000,145.0000
# Liaobatrachus,macilentus,113.0000,130.0000
# Liaobatrachus,beipiaoensis,122.4600,130.0000
# Liaobatrachus,grabaui,122.4600,130.0000
# Liaobatrachus,zhaoi,122.4600,130.0000
# Montsechobatrachus,gaudryi,125.0000,130.0000
# Eodiscoglossus,santonjae,125.4500,130.0000
# Gracilibatrachus,avallei,125.4500,130.0000
# Iberobatrachus,angelae,125.4500,130.0000
# Neusibatrachus,wilferti,125.0000,129.4000
# Arariphrynus,placidoi,112.0300,122.4600
# Cratia,gracilis,112.0300,122.4600
# Eurycephalella,alcinae,112.0300,122.4600
# Avitabatrachus,uliana,93.5000,99.6000
# Oumtkoutia,anae,93.5000,99.6000
# Aralobatrachus,robustus,86.3000,93.5000
# Estesina,elegans,86.3000,93.5000
# Gobiates,asiaticus,86.3000,93.5000
# Gobiates,dzhyrakudukensis,86.3000,93.5000
# Gobiates,kizylkumensis,86.3000,93.5000
# Kizylkuma,antiqua,86.3000,93.5000
# Saevesoederberghia,egredia,86.3000,93.5000
# Gobiates,tatarinovi,89.3000,93.5000
# Gobiatoides,parvus,89.3000,93.5000
# Procerobatrachus,paulus,89.3000,93.5000
# Baurubatrachus,pricei,83.6000,89.8000
# Gobiates,bogatchovi,86.3000,89.8000
# Gobiates,fritschi,86.3000,89.8000
# Gobiates,furcatus,86.3000,89.8000
# Gobiates,sosedkoi,86.3000,89.8000
# Gobiates,spinari,86.3000,89.8000
# Vulcanobatrachus,mandelai,66.0000,89.3000
# Pachycentrata,taqueti,83.6000,89.3000
# Bakonybatrachus,fedori,83.6000,86.3000
# Hungarobatrachus,szukacsi,83.6000,86.3000
# Cretasalia,tsybini,66.0000,83.6000
# Gobiates,khermeentsavi,66.0000,83.6000
# Gobiates,leptocolaptus,66.0000,83.6000
# Saltenia,ibanezi,72.1000,83.6000
# Scotiophryne,pustulosa,66.0000,83.5000
# Hensonbatrachus,kermiti,70.6000,83.5000
# Tyrrellbatrachus,brinkmani,70.6000,83.5000
# Eoxenopoides,reuningi,59.2000,72.1000
# Beelzebufo,ampinga,66.0000,72.1000
# Palaeobatrachus,occidentalis,66.0000,72.1000
# Uberabatrachus,carvalhoi,66.0000,72.1000
# Hatzegobatrachus,grigorescui,66.0000,70.6000
# Paradiscoglossus,americanus,66.0000,70.6000
# Paralatonia,transylvanica,66.0000,70.6000
# Theatonius,lancensis,66.0000,70.6000
# Estesiella,boliviensis,61.6000,66.0000
# Xenopus,romeri,48.6000,58.7000
# Prospea,holoserisca,55.8000,58.7000
# Bufo,serratus,15.9700,56.0000
# Rana,plicata,15.9700,56.0000
# Thaumastosaurus,bottii,15.9700,56.0000
# Llankibatrachus,truebae,28.4000,56.0000
# Indobatrachus,pusillus,33.9000,56.0000
# Shelania,laurenti,33.9000,56.0000
# Lechriodus,casca,47.8000,56.0000
# Eophractus,casamayorensis,48.0000,55.8000
# Eorubeta,nevadensis,48.6000,55.8000
# Eorhinophrynus,septentrionalis,46.2000,50.3000
# Shelania,pascuali,41.3000,47.8000
# Singidella,latecostata,41.3000,47.8000
# Chelomophrynus,bayi,40.4000,46.2000
# Elkobatrachus,brocki,40.4000,46.2000
# Albionbatrachus,wightensis,33.9000,37.2000
# Eopelobates,grandis,33.9000,37.2000
# Rhinophrynus,canadensis,33.9000,37.2000
# Thaumastosaurus,wardi,33.9000,37.2000
# Eopelobates,bayeri,11.6200,33.9000
# Xenopus,arabiensis,23.0300,33.9000
# Macropelobates,osborni,28.4000,33.9000
# Prodiscoglossus,vertaizoni,28.4000,33.9000
# Spea,neuter,13.6000,30.8000
# Tephrodytes,brassicarvalis,20.4300,30.8000
# Calyptocephalella,canqueli,21.0000,29.0000
# Neoprocoela,edentatus,21.0000,29.0000
# Australobatrachus,ilius,15.9700,28.4000
# Limnodynastes,archeri,15.9700,28.4000
# Litoria,caerulea,15.9700,28.4000
# Eopelobates,anthracinus,23.0300,28.4000
# Hyla,europaea,23.0300,28.4000
# Zaphrissa,eurypelis,23.0300,28.4000
# Rana,pipiens,0.0117,23.0300
# Latonia,ragei,13.6500,23.0300
# Palaeobatrachus,robustus,20.0000,22.4000
# Scaphiopus,holbrooki,0.0117,20.4300
# Bufo,praevius,15.9700,20.4300
# Hyla,goini,15.9700,20.4300
# Proacris,mintoni,15.9700,20.4300
# Leiopelma,acricarina,15.9000,19.0000
# Leiopelma,miocaenale,15.9000,19.0000
# Bufo,viridis,0.0000,16.9000
# Pelophylax,ridibunda,0.0117,16.9000
# Latonia,gigantea,3.6000,16.9000
# Wawelia,gerholdi,15.5000,16.3000
# Acris,crepitans,0.0117,15.9700
# Hyla,gratiosa,0.0117,15.9700
# Spea,bombifrons,0.0117,15.9700
# Hyla,versicolor,0.3000,15.9700
# Pseudacris,clarki,0.3000,15.9700
# Bufo,hibbardi,4.9000,15.9700
# Scaphiopus,wardorum,4.9000,15.9700
# Lechriodus,intergerivus,5.3330,15.9700
# Latonia,seyfriedi,8.7000,15.9700
# Bufo,valentinensis,10.3000,15.9700
# Hyla,squirella,10.3000,15.9700
# Scaphiopus,alexanderi,10.3000,15.9700
# Bufo,linquensis,11.6080,15.9700
# Miopelodytes,gilmorei,11.6080,15.9700
# Rana,basaltica,11.6080,15.9700
# Bufo,kuhrei,13.6000,15.9700
# Hyla,miocenica,13.6000,15.9700
# Pseudacris,nordensis,13.6000,15.9700
# Pelobates,fahlbuschi,13.6500,15.9700
# Hyla,cinerea,0.0117,13.6000
# Bufo,pliocompactilis,4.9000,13.6000
# Bufo,tiheni,4.9000,13.6000
# Rana,johnsoni,10.3000,13.6000
# Rana,pueyoi,8.7000,11.1000
# Rana,quellembergi,8.7000,11.1000
# Bufo,woodhousei,0.0000,10.3000
# Rana,catesbeiana,0.0117,10.3000
# Bufo,holmani,4.9000,10.3000
# Rana,temporaria,0.0117,5.3330
# Gastrophryne,carolinensis,0.0117,4.9000
# Anchylorana,dubita,1.8000,4.9000
# Anchylorana,moorei,1.8000,4.9000
# Anchylorana,robustocondyla,1.8000,4.9000
# Bufo,defensor,1.8000,4.9000
# Rana,bucella,1.8000,4.9000
# Rana,fayeae,1.8000,4.9000
# Rana,parvissima,1.8000,4.9000
# Rana,rexroadensis,1.8000,4.9000
# Spea,diversus,1.8000,4.9000
# Bufo,americanus,0.0117,2.5880
# Geocrinia,laevis,0.0117,2.5880
# Limnodynastes,dumerili,0.0117,2.5880
# Limnodynastes,tasmaniensis,0.0117,2.5880
# Litoria,ewingi,0.0117,2.5880
# Ranidella,signifera,0.0117,2.5880
# Bufo,terrestris,0.0117,1.8000
# Pseudacris,triseriata,0.0117,1.8000
# Odontophrynus,americanus,0.1260,0.7810
# Hyla,barbudensis,0.0000,0.1260
# Scaphiopus,couchi,0.0000,0.1260
# Spea,hammondii,0.0000,0.1260
# Acris,gryllus,0.0117,0.1260
# Hyla,baderi,0.0117,0.1260
# Pseudacris,ornata,0.0117,0.1260
# Rhinophrynus,dorsalis,0.0117,0.1260
# Syrrhophus,marnocki,0.0117,0.1260
# Rana,dalmatina,0.0000,0.0117

# %% [markdown]
# # 3) Using package PaleobioDB in R to help me create plots which can help me get closer to anwering my desired question (UPDATED):

# %% [markdown]
# # => What is Package PaleobioDB?
# * Includes 19 functions to wrap each endpoint of the PaleobioDB API, plus 8 functions to visualize and process the fossil data.

# %% [markdown]
# # => I ran this code in R:

# %% [markdown]
#   #install.packages("paleobioDB")
#     library(paleobioDB)
#
#     ## Loading required package: raster
#
#     ## Loading required package: sp
#
#     ## Loading required package: maps
#
#     #install.packages("devtools")
#     library(devtools)
#     install_github("ropensci/paleobioDB")
#
#     ## Skipping install of 'paleobioDB' from a github remote, the SHA1 (6fd8a94e) has not changed since last install.
#     ##   Use `force = TRUE` to force installation
#
#     library(paleobioDB)
#
# Defining "Anura"= frogs:
# ========================
#
# Give me a list of occurences and names:
# =======================================
#
#     frogs <-pbdb_occurrences (limit="all", vocab= "pbdb", base_name="Anura", show=c("coords", "phylo", "ident"))
#     head(frogs)
#
#     ##     occurrence_no record_type collection_no
#     ## 1:1        137378  occurrence         11576
#     ## 1:2        137379  occurrence         11576
#     ## 1:3        137433  occurrence         11582
#     ## 1:4        138862  occurrence         11806
#     ## 1:5        138866  occurrence         22634
#     ## 1:6        145954  occurrence         12816
#     ##                                taxon_name taxon_rank taxon_no
#     ## 1:1     Cretasalia n. gen. tsybini n. sp.    species   134552
#     ## 1:2                Gobiates leptocolaptus    species    58445
#     ## 1:3 Gobiates n. gen. khermeentsavi n. sp.    species   156388
#     ## 1:4                          Anura indet.      order    37422
#     ## 1:5                        Pipidae indet.     family    37435
#     ## 1:6  Enneabatrachus n. gen. hechti n. sp.    species    53192
#     ##               matched_name matched_rank matched_no early_interval
#     ## 1:1     Cretasalia tsybini      species     134552      Campanian
#     ## 1:2 Gobiates leptocolaptus      species      58445      Campanian
#     ## 1:3 Gobiates khermeentsavi      species     156388      Campanian
#     ## 1:4                  Anura        order     150288     Berriasian
#     ## 1:5                Pipidae       family      37435     Berriasian
#     ## 1:6  Enneabatrachus hechti      species      53192   Kimmeridgian
#     ##     late_interval early_age late_age reference_no        lng      lat
#     ## 1:1 Maastrichtian      83.6     66.0    4173;4173   99.60000 43.30000
#     ## 1:2 Maastrichtian      83.6     66.0    4173;4173   99.60000 43.30000
#     ## 1:3 Maastrichtian      83.6     66.0  30994;30994   99.60000 43.30000
#     ## 1:4   Valanginian     145.0    132.9    4203;4203   35.20000 31.00000
#     ## 1:5        Aptian     145.0    113.0    4203;4203   34.72666 30.53889
#     ## 1:6     Tithonian     157.3    145.0    4280;4280 -106.00222 41.89305
#     ##              genus genus_no         family family_no order order_no
#     ## 1:1     Cretasalia    86719     Gobiatidae     86720 Anura    97112
#     ## 1:2       Gobiates    37429     Gobiatidae     86720 Anura    97112
#     ## 1:3       Gobiates    37429     Gobiatidae     86720 Anura    97112
#     ## 1:4           <NA>       NA           <NA>        NA Anura    97112
#     ## 1:5           <NA>       NA        Pipidae     37435 Anura    97112
#     ## 1:6 Enneabatrachus    53191 Discoglossidae     37426 Anura    97112
#     ##        class class_no   phylum phylum_no     genus_name genus_reso
#     ## 1:1 Amphibia    36319 Chordata     33815     Cretasalia    n. gen.
#     ## 1:2 Amphibia    36319 Chordata     33815       Gobiates       <NA>
#     ## 1:3 Amphibia    36319 Chordata     33815       Gobiates    n. gen.
#     ## 1:4 Amphibia    36319 Chordata     33815          Anura       <NA>
#     ## 1:5 Amphibia    36319 Chordata     33815        Pipidae       <NA>
#     ## 1:6 Amphibia    36319 Chordata     33815 Enneabatrachus    n. gen.
#     ##      species_name species_reso reid_no subgenus_name subgenus_reso
#     ## 1:1       tsybini       n. sp.      NA          <NA>          <NA>
#     ## 1:2 leptocolaptus         <NA>      NA          <NA>          <NA>
#     ## 1:3 khermeentsavi       n. sp.      NA          <NA>          <NA>
#     ## 1:4        indet.         <NA>      NA          <NA>          <NA>
#     ## 1:5        indet.         <NA>      NA          <NA>          <NA>
#     ## 1:6        hechti       n. sp.      NA          <NA>          <NA>
#
# This provides me with the number of species my dataset has
# ==========================================================
#
# This also helps me make sure that my dataset is large enough(&gt;100):
# ======================================================================
#
#     pbdb_subtaxa (frogs, do.plot=TRUE)
#
# ![](week-9-r-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-3-1.png)
#
#     ##   species genera families orders classes phyla
#     ## 1     164    105       23      1       1     1
#
# Plot with the number of new appearances and last appearances of species, genera, families, etc. in your query across the time:
# ==============================================================================================================================
#
#     pbdb_orig_ext (frogs, rank="species", orig_ext=1, temporal_extent=c(0,200), res=10)
#
# ![](week-9-r-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-4-1.png)
#
#     ##                    new ext
#     ## 10-20 to 0-10        4  13
#     ## 20-30 to 10-20      20   5
#     ## 30-40 to 20-30      10   2
#     ## 40-50 to 30-40       6   5
#     ## 50-60 to 40-50       0   1
#     ## 60-70 to 50-60      11  12
#     ## 70-80 to 60-70       0   3
#     ## 80-90 to 70-80       8  10
#     ## 90-100 to 80-90      8   0
#     ## 100-110 to 90-100   10   0
#     ## 110-120 to 100-110   0   6
#     ## 120-130 to 110-120   0   7
#     ## 130-140 to 120-130   3   2
#     ## 140-150 to 130-140   8   3
#     ## 150-160 to 140-150   4   0
#     ## 160-170 to 150-160   3   0
#     ## 170-180 to 160-170   0   0
#     ## 180-190 to 170-180   0   0
#     ## 190-200 to 180-190   0   0
#
#     # extinction rates= orig_ext=2
#     pbdb_orig_ext(frogs, rank="species", orig_ext=2, temporal_extent=c(0,200), res=10)
#
# ![](week-9-r-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-5-1.png)
#
#     ##                    new ext
#     ## 10-20 to 0-10        4  13
#     ## 20-30 to 10-20      20   5
#     ## 30-40 to 20-30      10   2
#     ## 40-50 to 30-40       6   5
#     ## 50-60 to 40-50       0   1
#     ## 60-70 to 50-60      11  12
#     ## 70-80 to 60-70       0   3
#     ## 80-90 to 70-80       8  10
#     ## 90-100 to 80-90      8   0
#     ## 100-110 to 90-100   10   0
#     ## 110-120 to 100-110   0   6
#     ## 120-130 to 110-120   0   7
#     ## 130-140 to 120-130   3   2
#     ## 140-150 to 130-140   8   3
#     ## 150-160 to 140-150   4   0
#     ## 160-170 to 150-160   3   0
#     ## 170-180 to 160-170   0   0
#     ## 180-190 to 170-180   0   0
#     ## 190-200 to 180-190   0   0
#
# To combine things, this plots dataset species richness:a dataframe and a plot with the number of species (or genera, families, etc.) across time:
# =================================================================================================================================================
#
#     pbdb_richness (frogs, rank="species", temporal_extent=c(0,200), res=10)
#
# ![](week-9-r-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-6-1.png)
#
#     ##    temporal_intervals richness
#     ## 1                0-10       51
#     ## 2               10-20       49
#     ## 3               20-30       25
#     ## 4               30-40       16
#     ## 5               40-50       15
#     ## 6               50-60       13
#     ## 7               60-70       14
#     ## 8               70-80       16
#     ## 9               80-90       27
#     ## 10             90-100       12
#     ## 11            100-110        0
#     ## 12            110-120        6
#     ## 13            120-130       14
#     ## 14            130-140        4
#     ## 15            140-150        8
#     ## 16            150-160        4
#     ## 17            160-170        1
#     ## 18            170-180        0
#     ## 19            180-190        0
#     ## 20            190-200        0
#
# Finally, plot with the time span of the species:
# ================================================
#
#      pbdb_temp_range (frogs, rank="species")
#
# ![](week-9-r-paleobio-plots_files/figure-markdown_strict/unnamed-chunk-7-1.png)
#
#     ##                                        max      min
#     ## Eodiscoglossus oxoniensis         167.7000 164.7000
#     ## Comobatrachus aenigmatis          157.3000 145.0000
#     ## Enneabatrachus hechti             157.3000 145.0000
#     ## Eobatrachus agilis                157.3000 145.0000
#     ## Rhadinosteus parvus               157.3000 152.1000
#     ## Cordicephalus gracilis            145.0000 113.0000
#     ## Thoraciliacus rostriceps          145.0000 113.0000
#     ## Aygroua anoualensis               145.0000 139.8000
#     ## Shomronella jordanica             145.0000 139.8000
#     ## Sunnybatrachus purbeckensis       145.0000 140.2000
#     ## Liaobatrachus macilentus          130.0000 113.0000
#     ## Liaobatrachus beipiaoensis        130.0000 122.4600
#     ## Liaobatrachus grabaui             130.0000 122.4600
#     ## Liaobatrachus zhaoi               130.0000 122.4600
#     ## Montsechobatrachus gaudryi        130.0000 125.0000
#     ## Eodiscoglossus santonjae          130.0000 125.4500
#     ## Gracilibatrachus avallei          130.0000 125.4500
#     ## Iberobatrachus angelae            130.0000 125.4500
#     ## Neusibatrachus wilferti           129.4000 125.0000
#     ## Arariphrynus placidoi             122.4600 112.0300
#     ## Cratia gracilis                   122.4600 112.0300
#     ## Eurycephalella alcinae            122.4600 112.0300
#     ## Avitabatrachus uliana              99.6000  93.5000
#     ## Oumtkoutia anae                    99.6000  93.5000
#     ## Aralobatrachus robustus            93.5000  86.3000
#     ## Estesina elegans                   93.5000  86.3000
#     ## Gobiates asiaticus                 93.5000  86.3000
#     ## Gobiates dzhyrakudukensis          93.5000  86.3000
#     ## Gobiates kizylkumensis             93.5000  86.3000
#     ## Kizylkuma antiqua                  93.5000  86.3000
#     ## Saevesoederberghia egredia         93.5000  86.3000
#     ## Gobiates tatarinovi                93.5000  89.3000
#     ## Gobiatoides parvus                 93.5000  89.3000
#     ## Procerobatrachus paulus            93.5000  89.3000
#     ## Baurubatrachus pricei              89.8000  83.6000
#     ## Gobiates bogatchovi                89.8000  86.3000
#     ## Gobiates fritschi                  89.8000  86.3000
#     ## Gobiates furcatus                  89.8000  86.3000
#     ## Gobiates sosedkoi                  89.8000  86.3000
#     ## Gobiates spinari                   89.8000  86.3000
#     ## Vulcanobatrachus mandelai          89.3000  66.0000
#     ## Pachycentrata taqueti              89.3000  83.6000
#     ## Bakonybatrachus fedori             86.3000  83.6000
#     ## Hungarobatrachus szukacsi          86.3000  83.6000
#     ## Cretasalia tsybini                 83.6000  66.0000
#     ## Gobiates khermeentsavi             83.6000  66.0000
#     ## Gobiates leptocolaptus             83.6000  66.0000
#     ## Saltenia ibanezi                   83.6000  72.1000
#     ## Scotiophryne pustulosa             83.5000  66.0000
#     ## Hensonbatrachus kermiti            83.5000  70.6000
#     ## Tyrrellbatrachus brinkmani         83.5000  70.6000
#     ## Eoxenopoides reuningi              72.1000  59.2000
#     ## Beelzebufo ampinga                 72.1000  66.0000
#     ## Palaeobatrachus occidentalis       72.1000  66.0000
#     ## Uberabatrachus carvalhoi           72.1000  66.0000
#     ## Hatzegobatrachus grigorescui       70.6000  66.0000
#     ## Paradiscoglossus americanus        70.6000  66.0000
#     ## Paralatonia transylvanica          70.6000  66.0000
#     ## Theatonius lancensis               70.6000  66.0000
#     ## Estesiella boliviensis             66.0000  61.6000
#     ## Xenopus romeri                     58.7000  48.6000
#     ## Prospea holoserisca                58.7000  55.8000
#     ## Bufo serratus                      56.0000  15.9700
#     ## Rana plicata                       56.0000  15.9700
#     ## Thaumastosaurus bottii             56.0000  15.9700
#     ## Llankibatrachus truebae            56.0000  28.4000
#     ## Indobatrachus pusillus             56.0000  33.9000
#     ## Shelania laurenti                  56.0000  33.9000
#     ## Lechriodus casca                   56.0000  47.8000
#     ## Eophractus casamayorensis          55.8000  48.0000
#     ## Eorubeta nevadensis                55.8000  48.6000
#     ## Eorhinophrynus septentrionalis     50.3000  46.2000
#     ## Shelania pascuali                  47.8000  41.3000
#     ## Singidella latecostata             47.8000  41.3000
#     ## Chelomophrynus bayi                46.2000  40.4000
#     ## Elkobatrachus brocki               46.2000  40.4000
#     ## Albionbatrachus wightensis         37.2000  33.9000
#     ## Eopelobates grandis                37.2000  33.9000
#     ## Rhinophrynus canadensis            37.2000  33.9000
#     ## Thaumastosaurus wardi              37.2000  33.9000
#     ## Eopelobates bayeri                 33.9000  11.6200
#     ## Xenopus arabiensis                 33.9000  23.0300
#     ## Macropelobates osborni             33.9000  28.4000
#     ## Prodiscoglossus vertaizoni         33.9000  28.4000
#     ## Spea neuter                        30.8000  13.6000
#     ## Tephrodytes brassicarvalis         30.8000  20.4300
#     ## Calyptocephalella canqueli         29.0000  21.0000
#     ## Neoprocoela edentatus              29.0000  21.0000
#     ## Australobatrachus ilius            28.4000  15.9700
#     ## Limnodynastes archeri              28.4000  15.9700
#     ## Litoria caerulea                   28.4000  15.9700
#     ## Eopelobates anthracinus            28.4000  23.0300
#     ## Hyla europaea                      28.4000  23.0300
#     ## Zaphrissa eurypelis                28.4000  23.0300
#     ## Rana pipiens                       23.0300   0.0117
#     ## Latonia ragei                      23.0300  13.6500
#     ## Palaeobatrachus robustus           22.4000  20.0000
#     ## Scaphiopus (Scaphiopus) holbrooki  20.4300   0.0117
#     ## Bufo praevius                      20.4300  15.9700
#     ## Hyla goini                         20.4300  15.9700
#     ## Proacris mintoni                   20.4300  15.9700
#     ## Leiopelma acricarina               19.0000  15.9000
#     ## Leiopelma miocaenale               19.0000  15.9000
#     ## Bufo viridis                       16.9000   0.0000
#     ## Pelophylax ridibunda               16.9000   0.0117
#     ## Latonia gigantea                   16.9000   3.6000
#     ## Wawelia gerholdi                   16.3000  15.5000
#     ## Acris crepitans                    15.9700   0.0117
#     ## Hyla gratiosa                      15.9700   0.0117
#     ## Spea bombifrons                    15.9700   0.0117
#     ## Hyla versicolor                    15.9700   0.3000
#     ## Pseudacris clarki                  15.9700   0.3000
#     ## Bufo hibbardi                      15.9700   4.9000
#     ## Scaphiopus (Scaphiopus) wardorum   15.9700   4.9000
#     ## Lechriodus intergerivus            15.9700   5.3330
#     ## Latonia seyfriedi                  15.9700   8.7000
#     ## Bufo valentinensis                 15.9700  10.3000
#     ## Hyla squirella                     15.9700  10.3000
#     ## Scaphiopus (Spea) alexanderi       15.9700  10.3000
#     ## Bufo linquensis                    15.9700  11.6080
#     ## Miopelodytes gilmorei              15.9700  11.6080
#     ## Rana basaltica                     15.9700  11.6080
#     ## Bufo kuhrei                        15.9700  13.6000
#     ## Hyla miocenica                     15.9700  13.6000
#     ## Pseudacris nordensis               15.9700  13.6000
#     ## Pelobates fahlbuschi               15.9700  13.6500
#     ## Hyla cinerea                       13.6000   0.0117
#     ## Bufo pliocompactilis               13.6000   4.9000
#     ## Bufo tiheni                        13.6000   4.9000
#     ## Rana johnsoni                      13.6000  10.3000
#     ## Rana pueyoi                        11.1000   8.7000
#     ## Rana quellembergi                  11.1000   8.7000
#     ## Bufo woodhousei                    10.3000   0.0000
#     ## Rana catesbeiana                   10.3000   0.0117
#     ## Bufo holmani                       10.3000   4.9000
#     ## Rana temporaria                     5.3330   0.0117
#     ## Gastrophryne carolinensis           4.9000   0.0117
#     ## Anchylorana dubita                  4.9000   1.8000
#     ## Anchylorana moorei                  4.9000   1.8000
#     ## Anchylorana robustocondyla          4.9000   1.8000
#     ## Bufo defensor                       4.9000   1.8000
#     ## Rana bucella                        4.9000   1.8000
#     ## Rana fayeae                         4.9000   1.8000
#     ## Rana parvissima                     4.9000   1.8000
#     ## Rana rexroadensis                   4.9000   1.8000
#     ## Spea diversus                       4.9000   1.8000
#     ## Bufo americanus                     2.5880   0.0117
#     ## Geocrinia laevis                    2.5880   0.0117
#     ## Limnodynastes dumerili              2.5880   0.0117
#     ## Limnodynastes tasmaniensis          2.5880   0.0117
#     ## Litoria ewingi                      2.5880   0.0117
#     ## Ranidella signifera                 2.5880   0.0117
#     ## Bufo terrestris                     1.8000   0.0117
#     ## Pseudacris triseriata               1.8000   0.0117
#     ## Odontophrynus americanus            0.7810   0.1260
#     ## Hyla barbudensis                    0.1260   0.0000
#     ## Scaphiopus (Scaphiopus) couchi      0.1260   0.0000
#     ## Spea hammondii                      0.1260   0.0000
#     ## Acris gryllus                       0.1260   0.0117
#     ## Hyla baderi                         0.1260   0.0117
#     ## Pseudacris ornata                   0.1260   0.0117
#     ## Rhinophrynus dorsalis               0.1260   0.0117
#     ## Syrrhophus marnocki                 0.1260   0.0117
#     ## Rana dalmatina                      0.0117   0.0000

# %% [markdown]
# # 4) Using ggpplots to create diversity over time plot:
# # =>I ran these codes in R:
# # =>NOTE:
# * I have had a problem with running several of these codes because an error saying 'Discrete value supplied to continuous scale' pops up at certain time, not allowing me to successfully input all my desired codes
# * I went to prof. Alfaro's OH to talk to him abou this problem, and he said the following "your data needs to be cleaned a bit more. However, do NOT clean it manually on the csv file. Instead, use the shell commands to fix things  up"
# * Consequently, I did as I was told but the error still exists :(
# * Therefore, I ended once more writing out all of my own codes which I need to run on R to obtain the data and also a picture holder of how my plot will look like
# * I will go to prof. Alfaro / Guarav once more about my ggplot that I desire to obtain and how I can get rid of this error

# %% [markdown]
# #1 library(ggplot2)
#
#
# #2 frogs <- read.csv("/home/eeb177-student/Desktop/eeb-177/final-project/week-8-frog-data.csv", header = F, as.is = T)
#
# names(frogs) <- c("genus", "species", "minage", "maxage")
#
# head(frogs)
#
#
# #3 frogs_occ <- ggplot(frogs, aes( species, ymin = maxage, ymax=minage, colour = genus))
#
# frogs_occ <- frogs_occ + geom_linerange()
#
# frogs_occ
#
# #4 frogs_occ <- frogs_occ + theme(legend.position="none")
#
# frogs_occ
#
# #5 frogs_occ <- frogs_occ + coord_flip()
#
# frogs_occ
#
# #6 frogs_occ <- frogs_occ +  theme(axis.text.y = element_text(size=3))
#
# frogs_occ
#
# #7 frogs_occ <- frogs_occ + theme(axis.ticks.y=element_blank())
#
# frogs_occ
#
#
# #8 frogs_occ <- frogs_occ + scale_y_continuous(limits=c(0, 40), expand = c(0, 0), breaks=c(0, 10, 20, 30, 40))
#
# frogs_occ
#
# #9 frogs_occ <- frogs_occ + labs(title = "Frogs Fossil Occurrences", x = "Species", y = "Ma ago") + theme(plot.title = element_text(hjust = 0.5, size=22, face = "bold"), axis.title =element_text(size=20))
#
# frogs_occ

# %%
# Here is an example of how my graph will look like after implementing these codes in R:
# Note that I will populate my graph with my own data as written above in all the codes (FROGS)

from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/canids-graph-example.png')
